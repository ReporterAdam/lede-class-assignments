# %% [markdown]
# # Homework: Intro Scraping Practice
#
# In this assignment, we'll practicing our scraping skills by examining the "Published Reproductions" section of Soma's Investigate.ai project: https://investigate.ai/

# %% [markdown]
# ### 0) Setup
#
# Import `requests`, `BeautifulSoup`, and `pandas`. Remember that, even though we installed the library as `pip install beautifulsoup4`, the import statement uses a slightly different name.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### 1) Grab the HTML for https://investigate.ai/
#
# Use `requests` to get the HTML, assigning it to a variable

# %%
url = 'https://investigate.ai/'

response = requests.get(url)

html = response.text

# %% [markdown]
# ### 2) Use `BeautifulSoup` to convert the HTML into its DOM representation

# %%
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ### 3) Use `.select(...)` to select *just* the "Published reproductions" section
#
#
# You'll want "View Source" or pop open the Element Inspector to figure out which element to target.
#
# Reminder: An element's `class` attribute can contain *multiple* classes, separated by spaces. For example: `<div class="potato hamburger">Hello</div>` has two classes, `potato` and `hamburger`. A CSS selector for *either* of the classes — `soup.select(".potato")` *or* `soup.select(".hamburger")` — will both match that element.
#
# Hint: Look for a `div` with a particular class.

# %%
sections = soup.select('.section-projects')

# %% [markdown]
# ### 4) Use `projects_section.select(...)` to select elements that represent a single project
#
# Assign the list to a variable named `project_els`.

# %%
for projects_section in sections:
    project_els = projects_section.select('h5')

# %% [markdown]
# ### 5) Count the number of matching elements, using `len`
#
# Does it match the number of projects you see on the page? (It should.)

# %%
len(project_els)
# Out:
# 26

# %% [markdown]
# ### 6) For each project, print its title, publisher, summary, and link
#
# You'll want to construct a `for` loop. In each iteration of the loop, print out something that looks like this:
#
# ```
# Title: Searching for faulty airbags in vehicle complaints
#
# Publisher: The New York Times
#
# Summary: The National Highway Transportation Safety Administration receives thousands and thousands of vehicle complaints each year. Can we train a computer to filter out leads on Takata airbag malfunctions?
#
# Link: https://investigate.ai/nyt-takata-airbags/
# ---
# ```

# %%
titles = []
publishers = []
summaries = []
weblinks = []

for projects_section in sections:
    project_titles = projects_section.select('h5 a')
    for t in project_titles:
        title = t.get_text()
        titles.append(title)
    project_publishers = projects_section.select('.card-footer')
    for p in project_publishers:
        pub = p.get_text()
        pub2 = pub.strip()
        publishers.append(pub2)
    project_summaries = projects_section.select('.card-body p')
    for s in project_summaries:
        summ = s.get_text()
        summaries.append(summ)
    links = projects_section.select('h5 a')
    for l in links:
        link = l['href']
        webl = f'{url}{link}'
        weblinks.append(webl)
        

for title, publisher, summary, link in zip(titles, publishers, summaries, weblinks):
    print(f'Title: {title}')
    print('')
    print(f'Publisher: {publisher}')
    print('')
    print(f'Summary: {summary}')
    print('')
    print(f'Link: {url}{link}')
    print('---')
    print('')
# Out:
# Title: Searching for faulty airbags in vehicle complaints
#
# Publisher: The New York Times
#
# Summary: The National Highway Transportation Safety Administration receives thousands and thousands of vehicle complaints each year. Can we train a computer to filter out leads on Takata airbag malfunctions?
#
# Link: https://investigate.ai/https://investigate.ai//nyt-takata-airbags/
# ---
#
# Title: Building a crime classification engine
#
# Publisher: Los Angeles Times
#
# Summary: Using machine learning as an investigative tool to cast light on years of underreporting by the Los Angeles Police Department.
#
# Link: https://investigate.ai/https://investigate.ai//latimes-crime-classification/
# ---
#
# Title: Chinese museum analysis
#
# Publisher: Caixin
#
# Summary: A word-count analysis of the names of around 4500 museums in China.
#
# Link: https://investigate.ai/https://investigate.ai//caixin-museum-word-count/
# ---
#
# Title: Analyzing online safety through app store reviews
#
# Publisher: The Washington Post
#
# Summary: After downloading over a hundred thousand reviews of "random chat apps," how to find reports of bullying, racism, and unwanted sexual behavior.
#
# Link: https://investigate.ai/https://investigate.ai//wapo-app-reviews/
# ---
#
# Title: Uncovering abusive doctors that were allowed to continue practicing
#
# Publisher: Atlanta Journal-Constitution
#
# Summary: How to comb through 100,000 disciplinary documents without reading each individual one.
#
# Link: https://investigate.ai/https://investigate.ai//ajc-doctors-abuse/
# ---
#
# Title: Analyzing the tone of Trump's speeches
#
# Publisher: The New York Times
#
# Summary: Standard sentiment analysis scores a document on a positive-vs-negative scale. Using the Emotional Lexicon, though, you can add unique emotional measurements like anger, joy, surprise, or fear.
#
# Link: https://investigate.ai/https://investigate.ai//upshot-trump-emolex/
# ---
#
# Title: Detecting special interest model legislation in state laws
#
# Publisher: USA Today, The Arizona Republic, and the Center for Public Integrity
#
# Summary: Special interest groups use model legislation to push their agendas in state government. How can we find bills based on these "cut and paste" models?
#
# Link: https://investigate.ai/https://investigate.ai//azcentral-text-reuse-model-legislation/
# ---
#
# Title: Detecting bots in FCC comment submissions
#
# Publisher:
#
# Summary: The comment period on the FCC's net neutrality decision was flooded with bots. See how one still-in-training data scientist tackled finding re-used comments.
#
# Link: https://investigate.ai/https://investigate.ai//fcc-comments/
# ---
#
# Title: Figuring out what Democratic candidates care about
#
# Publisher: Bloomberg
#
# Summary: In the wide field of Democratic presidential candidates, who cares about what topics and how do these topics change over time?
#
# Link: https://investigate.ai/https://investigate.ai//bloomberg-tweet-topics/
# ---
#
# Title: What does Trump tweet about?
#
# Publisher: The New York Times
#
# Summary: What does Trump tweet about? An analysis of over 11,000 tweets.
#
# Link: https://investigate.ai/https://investigate.ai//nyt-trump-tweets/
# ---
#
# Title: Examining life expectancy at the local level
#
# Publisher: The Associated Press
#
# Summary: Combine geographically granular life expectancy data with the American Community Survey to see how poverty, education, income, and demographics can affect a community.
#
# Link: https://investigate.ai/https://investigate.ai//ap-regression-unemployment/
# ---
#
# Title: p values and p-hacking
#
# Publisher: FiveThirtyEight
#
# Summary: p-values and the quest for "statistical significance"
#
# Link: https://investigate.ai/https://investigate.ai//fivethirtyeight-p-hacking/
# ---
#
# Title: Predicting delays in patching potholes based on demographics
#
# Publisher: Milwaukee Journal-Sentinel
#
# Summary: An analysis of the relationship between race and city sanitation services in Milwaukee.
#
# Link: https://investigate.ai/https://investigate.ai//milwaukee-potholes/
# ---
#
# Title: Finding cheating schools in Texas with linear regression
#
# Publisher: Dallas Morning News
#
# Summary: Some schools in Texas had an odd jump in standardized test scores between different grades. Was it cheating? Linear regression is on the case!
#
# Link: https://investigate.ai/https://investigate.ai//dmn-texas-school-cheating/
# ---
#
# Title: Measuring the impact of re-segregation on Florida elementary schools
#
# Publisher: Tampa Bay Times
#
# Summary: Using race, income, and other data to predict the performance of schools in Pinellas County, Florida. Along with a linear regression-driven critique.
#
# Link: https://investigate.ai/https://investigate.ai//tampa-bay-times-schools/
# ---
#
# Title: Analyzing whether larger cars cause more deadly crashes
#
# Publisher: Review of Economic Studies
#
# Summary: Reproducing a research paper on the impact of weight on car accidents, along with a look at a state-based car crash database.
#
# Link: https://investigate.ai/https://investigate.ai//car-crashes-weight-regression/
# ---
#
# Title: Tracking equal access to school programs
#
# Publisher: ProPublica
#
# Summary: Looking at differences in access to advanced classes between schools with wealthy students and schools with poor students.
#
# Link: https://investigate.ai/https://investigate.ai//propublica-opportunity-gap/
# ---
#
# Title: Investigating who gets a ticket and who gets a warning
#
# Publisher: The Boston Globe
#
# Summary: A classic piece of data journalism analyzing ticketing by Massachusetts police, and whether the race or gender of the driver might change the outcome.
#
# Link: https://investigate.ai/https://investigate.ai//boston-globe-tickets/
# ---
#
# Title: Stanford Open Policing Data
#
# Publisher:
#
# Summary: A giant dataset of standardized data policing data across different states
#
# Link: https://investigate.ai/https://investigate.ai//stanford-open-policing/
# ---
#
# Title: Uncovering surveillance planes with BuzzFeed
#
# Publisher: BuzzFeed News
#
# Summary: From a list of points along a flight's path, how can you say "this looks like a surveillance plane?" And once you've found them, what do you do with the results?
#
# Link: https://investigate.ai/https://investigate.ai//buzzfeed-spy-planes/
# ---
#
# Title: Analyzing mortgage rejections for racial bias
#
# Publisher: Reveal
#
# Summary: Based on government-mandated data collection on mortgage granting, are certain banks or areas discriminatory in their lending practices?
#
# Link: https://investigate.ai/https://investigate.ai//reveal-mortgages/
# ---
#
# Title: Bias in the jury selection process
#
# Publisher: APM Reports
#
# Summary: When selecting a jury, both the defense and the prosecution are allowed to strike potential jurors from the pool. While the potential jurors provide answers to a questionnaire, what kind of role might race play in their selection or rejection?
#
# Link: https://investigate.ai/https://investigate.ai//apm-reports-jury-bias/
# ---
#
# Title: Analyzing the impact of particular judges on the US asylum process
#
# Publisher: Reuters
#
# Summary: In U.S. immigration courts, are certain judges and locations more likely to approve or deny claims of asylum?
#
# Link: https://investigate.ai/https://investigate.ai//reuters-asylum/
# ---
#
# Title: Investigating who receives presidential pardons
#
# Publisher: ProPublica
#
# Summary: An analysis of the presidential pardon process, but also a look into what to do when a very personal dataset doesn't exist.
#
# Link: https://investigate.ai/https://investigate.ai//propublica-pardons/
# ---
#
# Title: An analysis of racial bias in criminal sentencing
#
# Publisher: ProPublica
#
# Summary: Can an algorithm be racist? An examination of the COMPAS algorithm used as an aid in making sentencing and parole decisions. Also featuring a critique of the critique!
#
# Link: https://investigate.ai/https://investigate.ai//propublica-criminal-sentencing/
# ---
#
# Title: Predicting FOIA requests success rates
#
# Publisher: data.world
#
# Summary: Government agencies seem to fulfill or reject FOIA request without rhyme or reason. Can a journalist use machine learning to improve their chances?
#
# Link: https://investigate.ai/https://investigate.ai//foia-predictor/
# ---

# %% [markdown]
# ### 7) Now, let's do the same thing, but storing the info in a `pandas` `DataFrame`
#
# Specifically, a `DataFrame` with the columns `title`, `publisher`, `summary`, and `link`.

# %%
data = {
    'Title': titles,
    'Publisher': publishers,
    'Summary': summaries,
    'Link': weblinks
}
df = pd.DataFrame(data)

df
# Out:
#                                                 Title  \
# 0   Searching for faulty airbags in vehicle compla...
# 1              Building a crime classification engine
# 2                             Chinese museum analysis
# 3   Analyzing online safety through app store reviews
# 4   Uncovering abusive doctors that were allowed t...
# 5              Analyzing the tone of Trump's speeches
# 6   Detecting special interest model legislation i...
# 7           Detecting bots in FCC comment submissions
# 8   Figuring out what Democratic candidates care a...
# 9                        What does Trump tweet about?
# 10       Examining life expectancy at the local level
# 11                             p values and p-hacking
# 12  Predicting delays in patching potholes based o...
# 13  Finding cheating schools in Texas with linear ...
# 14  Measuring the impact of re-segregation on Flor...
# 15  Analyzing whether larger cars cause more deadl...
# 16           Tracking equal access to school programs
# 17  Investigating who gets a ticket and who gets a...
# 18                        Stanford Open Policing Data
# 19       Uncovering surveillance planes with BuzzFeed
# 20      Analyzing mortgage rejections for racial bias
# 21                 Bias in the jury selection process
# 22  Analyzing the impact of particular judges on t...
# 23    Investigating who receives presidential pardons
# 24  An analysis of racial bias in criminal sentencing
# 25             Predicting FOIA requests success rates
#
#                                             Publisher  \
# 0                                  The New York Times
# 1                                   Los Angeles Times
# 2                                              Caixin
# 3                                 The Washington Post
# 4                        Atlanta Journal-Constitution
# 5                                  The New York Times
# 6   USA Today, The Arizona Republic, and the Cente...
# 7
# 8                                           Bloomberg
# 9                                  The New York Times
# 10                               The Associated Press
# 11                                    FiveThirtyEight
# 12                         Milwaukee Journal-Sentinel
# 13                                Dallas Morning News
# 14                                    Tampa Bay Times
# 15                         Review of Economic Studies
# 16                                         ProPublica
# 17                                   The Boston Globe
# 18
# 19                                      BuzzFeed News
# 20                                             Reveal
# 21                                        APM Reports
# 22                                            Reuters
# 23                                         ProPublica
# 24                                         ProPublica
# 25                                         data.world
#
#                                               Summary  \
# 0   The National Highway Transportation Safety Adm...
# 1   Using machine learning as an investigative too...
# 2   A word-count analysis of the names of around 4...
# 3   After downloading over a hundred thousand revi...
# 4   How to comb through 100,000 disciplinary docum...
# 5   Standard sentiment analysis scores a document ...
# 6   Special interest groups use model legislation ...
# 7   The comment period on the FCC's net neutrality...
# 8   In the wide field of Democratic presidential c...
# 9   What does Trump tweet about? An analysis of ov...
# 10  Combine geographically granular life expectanc...
# 11  p-values and the quest for "statistical signif...
# 12  An analysis of the relationship between race a...
# 13  Some schools in Texas had an odd jump in stand...
# 14  Using race, income, and other data to predict ...
# 15  Reproducing a research paper on the impact of ...
# 16  Looking at differences in access to advanced c...
# 17  A classic piece of data journalism analyzing t...
# 18  A giant dataset of standardized data policing ...
# 19  From a list of points along a flight's path, h...
# 20  Based on government-mandated data collection o...
# 21  When selecting a jury, both the defense and th...
# 22  In U.S. immigration courts, are certain judges...
# 23  An analysis of the presidential pardon process...
# 24  Can an algorithm be racist? An examination of ...
# 25  Government agencies seem to fulfill or reject ...
#
#                                                  Link
# 0         https://investigate.ai//nyt-takata-airbags/
# 1   https://investigate.ai//latimes-crime-classifi...
# 2   https://investigate.ai//caixin-museum-word-count/
# 3           https://investigate.ai//wapo-app-reviews/
# 4          https://investigate.ai//ajc-doctors-abuse/
# 5        https://investigate.ai//upshot-trump-emolex/
# 6   https://investigate.ai//azcentral-text-reuse-m...
# 7               https://investigate.ai//fcc-comments/
# 8     https://investigate.ai//bloomberg-tweet-topics/
# 9           https://investigate.ai//nyt-trump-tweets/
# 10  https://investigate.ai//ap-regression-unemploy...
# 11  https://investigate.ai//fivethirtyeight-p-hack...
# 12        https://investigate.ai//milwaukee-potholes/
# 13  https://investigate.ai//dmn-texas-school-cheat...
# 14   https://investigate.ai//tampa-bay-times-schools/
# 15  https://investigate.ai//car-crashes-weight-reg...
# 16  https://investigate.ai//propublica-opportunity...
# 17      https://investigate.ai//boston-globe-tickets/
# 18    https://investigate.ai//stanford-open-policing/
# 19       https://investigate.ai//buzzfeed-spy-planes/
# 20          https://investigate.ai//reveal-mortgages/
# 21     https://investigate.ai//apm-reports-jury-bias/
# 22            https://investigate.ai//reuters-asylum/
# 23        https://investigate.ai//propublica-pardons/
# 24  https://investigate.ai//propublica-criminal-se...
# 25            https://investigate.ai//foia-predictor/

# %% [markdown]
# ### 8) Using that `DataFrame`, calculate:

# %% [markdown]
# Who are the most-featured publishers?

# %%
top_pub = df['Publisher'].value_counts()

top_pub
# Out:
# Publisher
# The New York Times                                                      3
# ProPublica                                                              3
#                                                                         2
# Los Angeles Times                                                       1
# Caixin                                                                  1
# Atlanta Journal-Constitution                                            1
# The Washington Post                                                     1
# Bloomberg                                                               1
# USA Today, The Arizona Republic, and the Center for Public Integrity    1
# FiveThirtyEight                                                         1
# Milwaukee Journal-Sentinel                                              1
# Dallas Morning News                                                     1
# The Associated Press                                                    1
# Tampa Bay Times                                                         1
# Review of Economic Studies                                              1
# The Boston Globe                                                        1
# BuzzFeed News                                                           1
# Reveal                                                                  1
# APM Reports                                                             1
# Reuters                                                                 1
# data.world                                                              1
# Name: count, dtype: int64

# %% [markdown]
# Which project has the longest summary, in number of characters of text? How long is it?

# %%
df['Summary-Length'] = df['Summary'].apply(len)

df.sort_values(by='Summary-Length', ascending=False)
# Out:
#                                                 Title  \
# 21                 Bias in the jury selection process
# 0   Searching for faulty airbags in vehicle compla...
# 5              Analyzing the tone of Trump's speeches
# 10       Examining life expectancy at the local level
# 24  An analysis of racial bias in criminal sentencing
# 19       Uncovering surveillance planes with BuzzFeed
# 7           Detecting bots in FCC comment submissions
# 17  Investigating who gets a ticket and who gets a...
# 14  Measuring the impact of re-segregation on Flor...
# 6   Detecting special interest model legislation i...
# 25             Predicting FOIA requests success rates
# 3   Analyzing online safety through app store reviews
# 13  Finding cheating schools in Texas with linear ...
# 20      Analyzing mortgage rejections for racial bias
# 1              Building a crime classification engine
# 8   Figuring out what Democratic candidates care a...
# 15  Analyzing whether larger cars cause more deadl...
# 23    Investigating who receives presidential pardons
# 16           Tracking equal access to school programs
# 22  Analyzing the impact of particular judges on t...
# 4   Uncovering abusive doctors that were allowed t...
# 12  Predicting delays in patching potholes based o...
# 18                        Stanford Open Policing Data
# 2                             Chinese museum analysis
# 9                        What does Trump tweet about?
# 11                             p values and p-hacking
#
#                                             Publisher  \
# 21                                        APM Reports
# 0                                  The New York Times
# 5                                  The New York Times
# 10                               The Associated Press
# 24                                         ProPublica
# 19                                      BuzzFeed News
# 7
# 17                                   The Boston Globe
# 14                                    Tampa Bay Times
# 6   USA Today, The Arizona Republic, and the Cente...
# 25                                         data.world
# 3                                 The Washington Post
# 13                                Dallas Morning News
# 20                                             Reveal
# 1                                   Los Angeles Times
# 8                                           Bloomberg
# 15                         Review of Economic Studies
# 23                                         ProPublica
# 16                                         ProPublica
# 22                                            Reuters
# 4                        Atlanta Journal-Constitution
# 12                         Milwaukee Journal-Sentinel
# 18
# 2                                              Caixin
# 9                                  The New York Times
# 11                                    FiveThirtyEight
#
#                                               Summary  \
# 21  When selecting a jury, both the defense and th...
# 0   The National Highway Transportation Safety Adm...
# 5   Standard sentiment analysis scores a document ...
# 10  Combine geographically granular life expectanc...
# 24  Can an algorithm be racist? An examination of ...
# 19  From a list of points along a flight's path, h...
# 7   The comment period on the FCC's net neutrality...
# 17  A classic piece of data journalism analyzing t...
# 14  Using race, income, and other data to predict ...
# 6   Special interest groups use model legislation ...
# 25  Government agencies seem to fulfill or reject ...
# 3   After downloading over a hundred thousand revi...
# 13  Some schools in Texas had an odd jump in stand...
# 20  Based on government-mandated data collection o...
# 1   Using machine learning as an investigative too...
# 8   In the wide field of Democratic presidential c...
# 15  Reproducing a research paper on the impact of ...
# 23  An analysis of the presidential pardon process...
# 16  Looking at differences in access to advanced c...
# 22  In U.S. immigration courts, are certain judges...
# 4   How to comb through 100,000 disciplinary docum...
# 12  An analysis of the relationship between race a...
# 18  A giant dataset of standardized data policing ...
# 2   A word-count analysis of the names of around 4...
# 9   What does Trump tweet about? An analysis of ov...
# 11  p-values and the quest for "statistical signif...
#
#                                                  Link  SummaryLength  \
# 21     https://investigate.ai//apm-reports-jury-bias/            243
# 0         https://investigate.ai//nyt-takata-airbags/            198
# 5        https://investigate.ai//upshot-trump-emolex/            193
# 10  https://investigate.ai//ap-regression-unemploy...            167
# 24  https://investigate.ai//propublica-criminal-se...            167
# 19       https://investigate.ai//buzzfeed-spy-planes/            161
# 7               https://investigate.ai//fcc-comments/            157
# 17      https://investigate.ai//boston-globe-tickets/            150
# 14   https://investigate.ai//tampa-bay-times-schools/            149
# 6   https://investigate.ai//azcentral-text-reuse-m...            149
# 25            https://investigate.ai//foia-predictor/            147
# 3           https://investigate.ai//wapo-app-reviews/            143
# 13  https://investigate.ai//dmn-texas-school-cheat...            142
# 20          https://investigate.ai//reveal-mortgages/            136
# 1   https://investigate.ai//latimes-crime-classifi...            126
# 8     https://investigate.ai//bloomberg-tweet-topics/            126
# 15  https://investigate.ai//car-crashes-weight-reg...            125
# 23        https://investigate.ai//propublica-pardons/            123
# 16  https://investigate.ai//propublica-opportunity...            122
# 22            https://investigate.ai//reuters-asylum/            109
# 4          https://investigate.ai//ajc-doctors-abuse/             87
# 12        https://investigate.ai//milwaukee-potholes/             87
# 18    https://investigate.ai//stanford-open-policing/             74
# 2   https://investigate.ai//caixin-museum-word-count/             67
# 9           https://investigate.ai//nyt-trump-tweets/             63
# 11  https://investigate.ai//fivethirtyeight-p-hack...             53
#
#     Summary-Length
# 21             243
# 0              198
# 5              193
# 10             167
# 24             167
# 19             161
# 7              157
# 17             150
# 14             149
# 6              149
# 25             147
# 3              143
# 13             142
# 20             136
# 1              126
# 8              126
# 15             125
# 23             123
# 16             122
# 22             109
# 4               87
# 12              87
# 18              74
# 2               67
# 9               63
# 11              53

# %% [markdown]
# How many times longer is it than the average summary?

# %%
median_length = df['Summary-Length'].median()
top_length = 243

top_length - median_length
# Out:
# 104.0

# %% [markdown]
# ---
#
# ---
#
# ---
